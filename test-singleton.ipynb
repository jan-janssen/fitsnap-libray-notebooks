# %%
from mpi4py import MPI

# %%
comm = MPI.COMM_WORLD

# %%
from fitsnap3.parallel_tools import ParallelTools

# %%
pt = ParallelTools(comm=comm)

# %%
pt.fitsnap_dict
# Out:
# {}

# %%
from fitsnap3.io.input import Config

# %%
config = Config(arguments_lst = ["Ta-example.in","--overwrite"])

# %%
pt.fitsnap_dict
# Out:
# {'energy': 1, 'force': 1, 'stress': 1}

# %%
pt.fitsnap_dict = {}

# %%
pt

# %%
pt.shared_arrays
# Out:
# {}

# %%
config.sections
# Out:
# {'EXTRAS': <fitsnap3.io.sections.extras.Extras at 0x11b964be0>,
#  'SCRAPER': <fitsnap3.io.sections.scraper.Scraper at 0x11b9741f0>,
#  'SOLVER': <fitsnap3.io.sections.solver.Solver at 0x11b974250>,
#  'MEMORY': <fitsnap3.io.sections.memory.Memory at 0x11b974610>,
#  'OUTFILE': <fitsnap3.io.sections.outfile.Outfile at 0x11b9745e0>,
#  'GROUPS': <fitsnap3.io.sections.groups.Groups at 0x11b9745b0>,
#  'CALCULATOR': <fitsnap3.io.sections.calculator.Calculator at 0x11b974700>,
#  'DEFAULT': <fitsnap3.io.sections.template.Default at 0x11b974670>,
#  'REFERENCE': <fitsnap3.io.sections.reference.Reference at 0x11b9746a0>,
#  'ESHIFT': <fitsnap3.io.sections.eshift.Eshift at 0x11b974760>,
#  'PATH': <fitsnap3.io.sections.path.Path at 0x11b9746d0>,
#  'BISPECTRUM': <fitsnap3.io.sections.bispectrum.Bispectrum at 0x11b9747c0>}

# %%
from fitsnap3.parallel_tools import ParallelTools

# %%
pt = ParallelTools(comm=None)

# %%
pt.__init__(comm=comm)

# %%
pt

# %%
pt.fitsnap_dict
# Out:
# {}

# %%
from fitsnap3.io.input import Config

# %%
config.sections = {}

# %%
config.sections
# Out:
# {}

# %%
pt.fitsnap_dict
# Out:
# {}

# %%
config = Config(arguments_lst = ["Ta-example.in","--overwrite"])
